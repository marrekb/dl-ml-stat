# %%
import pandas as pd 
import numpy as np 
import sklearn
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split
import tensorflow as tf

pd.__version__, np.__version__, sklearn.__version__, tf.__version__
# Out:
# ('1.3.5', '1.21.6', '1.0.2', '2.8.2')

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/marrekb/dl-ml-stat/main/02_tennis_winner_prediction/dataset.csv')

y = dataset['result'].to_numpy() 
X = dataset.drop('result', axis = 1)

columns_to_scale = ['age_diff', 'rank_diff', 'win_diff', 'loss_diff', 'swin_diff', 'sloss_diff']
scaler = StandardScaler()
scaler.fit(X[columns_to_scale])

scaled_X = scaler.transform(X[columns_to_scale])
df_scaled_X = pd.DataFrame(scaled_X, columns = columns_to_scale)
df_scaled_X.describe()

con_X = np.concatenate((scaled_X, X[['p1_hand_L', 'p1_hand_R', 'p1_hand_U', 'p2_hand_L', 'p2_hand_R', 'p2_hand_U']].to_numpy()), axis = 1)

x_train, x_test, y_train, y_test = train_test_split(con_X, y, test_size = 0.2, random_state = 42)
x_train.shape, y_test.shape
# Out:
# ((660099, 12), (165025,))

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
def measure_with_bound_core(y_true, y_pred, lower_bound, upper_bound, return_count = False):
  zeros_idx = y_pred <= lower_bound
  ones_idx = y_pred >= upper_bound 

  true_zeros =  y_true[zeros_idx] == 0
  true_ones = y_true[ones_idx] == 1

  true_zeros_sum = tf.reduce_sum(tf.cast(true_zeros, dtype = tf.float32))
  true_ones_sum = tf.reduce_sum(tf.cast(true_ones, dtype = tf.float32))

  zeros_sum = tf.reduce_sum(tf.cast(zeros_idx, dtype = tf.float32))
  ones_sum = tf.reduce_sum(tf.cast(ones_idx, dtype = tf.float32))
  
  count = zeros_sum + ones_sum
  if count == 0:
    count = tf.constant([1.0], dtype = tf.float32)
  if return_count:
    return (true_zeros_sum + true_ones_sum) / count, count
  return (true_zeros_sum + true_ones_sum) / count

def measure_with_bound2(y_true, y_pred):
  lower_bound = 0.3
  upper_bound = 0.7 

  return measure_with_bound_core(y_true, y_pred, lower_bound, upper_bound)

def measure_with_bound1(y_true, y_pred):
  lower_bound = 0.4
  upper_bound = 0.6 

  return measure_with_bound_core(y_true, y_pred, lower_bound, upper_bound)

def measure_with_bound3(y_true, y_pred):
  lower_bound = 0.2
  upper_bound = 0.8 

  return measure_with_bound_core(y_true, y_pred, lower_bound, upper_bound)

# %%
model = tf.keras.Sequential([
  tf.keras.layers.Dense(64, activation = 'relu', input_shape = (12,)),
  tf.keras.layers.Dense(64, activation = 'relu'),
  tf.keras.layers.Dense(1, activation = 'sigmoid')
])

model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.001),
              loss = tf.keras.losses.BinaryCrossentropy(),
              metrics = [tf.keras.metrics.BinaryAccuracy(), measure_with_bound1, measure_with_bound2, measure_with_bound3])

model.fit(x_train, y_train, epochs = 20, batch_size=512)
# Out:
# Epoch 1/20
# 1290/1290 [==============================] - 13s 8ms/step - loss: 0.6108 - binary_accuracy: 0.6706 - measure_with_bound1: 0.7218 - measure_with_bound2: 0.7764 - measure_with_bound3: 0.8382
# Epoch 2/20
# 1290/1290 [==============================] - 10s 8ms/step - loss: 0.6036 - binary_accuracy: 0.6776 - measure_with_bound1: 0.7242 - measure_with_bound2: 0.7861 - measure_with_bound3: 0.8512
# Epoch 3/20
# 1290/1290 [==============================] - 7s 5ms/step - loss: 0.5998 - binary_accuracy: 0.6806 - measure_with_bound1: 0.7272 - measure_with_bound2: 0.7910 - measure_with_bound3: 0.8528
# Epoch 4/20
# 1290/1290 [==============================] - 6s 4ms/step - loss: 0.5971 - binary_accuracy: 0.6827 - measure_with_bound1: 0.7291 - measure_with_bound2: 0.7925 - measure_with_bound3: 0.8542
# Epoch 5/20
# 1290/1290 [==============================] - 6s 4ms/step - loss: 0.5954 - binary_accuracy: 0.6837 - measure_with_bound1: 0.7310 - measure_with_bound2: 0.7937 - measure_with_bound3: 0.8533
# Epoch 6/20
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5941 - binary_accuracy: 0.6845 - measure_with_bound1: 0.7332 - measure_with_bound2: 0.7942 - measure_with_bound3: 0.8539
# Epoch 7/20
# 1290/1290 [==============================] - 6s 4ms/step - loss: 0.5928 - binary_accuracy: 0.6851 - measure_with_bound1: 0.7346 - measure_with_bound2: 0.7952 - measure_with_bound3: 0.8530
# Epoch 8/20
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5917 - binary_accuracy: 0.6860 - measure_with_bound1: 0.7363 - measure_with_bound2: 0.7959 - measure_with_bound3: 0.8529
# Epoch 9/20
# 1290/1290 [==============================] - 6s 4ms/step - loss: 0.5910 - binary_accuracy: 0.6866 - measure_with_bound1: 0.7376 - measure_with_bound2: 0.7955 - measure_with_bound3: 0.8533
# Epoch 10/20
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5904 - binary_accuracy: 0.6869 - measure_with_bound1: 0.7387 - measure_with_bound2: 0.7961 - measure_with_bound3: 0.8530
# Epoch 11/20
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5898 - binary_accuracy: 0.6872 - measure_with_bound1: 0.7390 - measure_with_bound2: 0.7960 - measure_with_bound3: 0.8536
# Epoch 12/20
# 1290/1290 [==============================] - 6s 4ms/step - loss: 0.5893 - binary_accuracy: 0.6873 - measure_with_bound1: 0.7400 - measure_with_bound2: 0.7967 - measure_with_bound3: 0.8536
# Epoch 13/20
# 1290/1290 [==============================] - 6s 4ms/step - loss: 0.5889 - binary_accuracy: 0.6877 - measure_with_bound1: 0.7406 - measure_with_bound2: 0.7969 - measure_with_bound3: 0.8536
# Epoch 14/20
# 1290/1290 [==============================] - 6s 4ms/step - loss: 0.5886 - binary_accuracy: 0.6878 - measure_with_bound1: 0.7408 - measure_with_bound2: 0.7969 - measure_with_bound3: 0.8543
# Epoch 15/20
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5885 - binary_accuracy: 0.6880 - measure_with_bound1: 0.7413 - measure_with_bound2: 0.7972 - measure_with_bound3: 0.8538
# Epoch 16/20
# 1290/1290 [==============================] - 6s 4ms/step - loss: 0.5881 - binary_accuracy: 0.6880 - measure_with_bound1: 0.7418 - measure_with_bound2: 0.7983 - measure_with_bound3: 0.8532
# Epoch 17/20
# 1290/1290 [==============================] - 6s 4ms/step - loss: 0.5880 - binary_accuracy: 0.6885 - measure_with_bound1: 0.7419 - measure_with_bound2: 0.7975 - measure_with_bound3: 0.8534
# Epoch 18/20
# 1290/1290 [==============================] - 6s 4ms/step - loss: 0.5877 - binary_accuracy: 0.6884 - measure_with_bound1: 0.7420 - measure_with_bound2: 0.7981 - measure_with_bound3: 0.8532
# Epoch 19/20
# 1290/1290 [==============================] - 6s 4ms/step - loss: 0.5877 - binary_accuracy: 0.6884 - measure_with_bound1: 0.7425 - measure_with_bound2: 0.7981 - measure_with_bound3: 0.8530
# Epoch 20/20
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5875 - binary_accuracy: 0.6887 - measure_with_bound1: 0.7426 - measure_with_bound2: 0.7978 - measure_with_bound3: 0.8531

# %%
model.evaluate(x_test, y_test, batch_size = 2048)
# Out:
# 81/81 [==============================] - 1s 4ms/step - loss: 0.5877 - binary_accuracy: 0.6889 - measure_with_bound1: 0.7471 - measure_with_bound2: 0.8038 - measure_with_bound3: 0.8603
# [0.587731659412384,
#  0.6888956427574158,
#  0.7470558285713196,
#  0.8037779927253723,
#  0.8602906465530396]

# %%
dataset = tf.data.Dataset.from_tensor_slices(x_test).batch(2048)

predictions = None

for x in dataset:
  pred = model(x)
  if predictions == None:
    predictions = pred
  else:
    predictions = tf.concat([predictions, pred], axis = 0)

# %%
y = tf.reshape(tf.constant(y_test), shape = [-1, 1])

for i in range(5, 50, 5):
  b = i / 100.0
  acc, count = measure_with_bound_core(y, predictions, 0.5 - b, 0.5 + b, True)
  print('bound: {b:.2f}, accuracy: {acc: .4f}, count: {count}'.format(b = 0.5 + b, acc = acc, count = int(count)))
# Out:
# bound: 0.55, accuracy:  0.7188, count: 140434
# bound: 0.60, accuracy:  0.7471, count: 116508
# bound: 0.65, accuracy:  0.7741, count: 92818
# bound: 0.70, accuracy:  0.8037, count: 69856
# bound: 0.75, accuracy:  0.8312, count: 48309
# bound: 0.80, accuracy:  0.8601, count: 29014
# bound: 0.85, accuracy:  0.8862, count: 13558
# bound: 0.90, accuracy:  0.9099, count: 3653
# bound: 0.95, accuracy:  0.9103, count: 290

# %%
model2 = tf.keras.Sequential([
  tf.keras.layers.Dense(96, activation = 'relu', input_shape = (12,)),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(96, activation = 'relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(96, activation = 'relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(1, activation = 'sigmoid')
])

model2.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.001),
              loss = tf.keras.losses.BinaryCrossentropy(),
              metrics = [tf.keras.metrics.BinaryAccuracy(), measure_with_bound1, measure_with_bound2, measure_with_bound3])

model2.fit(x_train, y_train, epochs = 30, batch_size=512)
# Out:
# Epoch 1/30
# 1290/1290 [==============================] - 7s 5ms/step - loss: 0.6142 - binary_accuracy: 0.6689 - measure_with_bound1: 0.7173 - measure_with_bound2: 0.7762 - measure_with_bound3: 0.8318
# Epoch 2/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.6055 - binary_accuracy: 0.6772 - measure_with_bound1: 0.7192 - measure_with_bound2: 0.7860 - measure_with_bound3: 0.8430
# Epoch 3/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.6008 - binary_accuracy: 0.6809 - measure_with_bound1: 0.7249 - measure_with_bound2: 0.7895 - measure_with_bound3: 0.8465
# Epoch 4/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5983 - binary_accuracy: 0.6820 - measure_with_bound1: 0.7293 - measure_with_bound2: 0.7904 - measure_with_bound3: 0.8479
# Epoch 5/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5970 - binary_accuracy: 0.6830 - measure_with_bound1: 0.7320 - measure_with_bound2: 0.7920 - measure_with_bound3: 0.8478
# Epoch 6/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5958 - binary_accuracy: 0.6837 - measure_with_bound1: 0.7328 - measure_with_bound2: 0.7929 - measure_with_bound3: 0.8488
# Epoch 7/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5950 - binary_accuracy: 0.6841 - measure_with_bound1: 0.7353 - measure_with_bound2: 0.7939 - measure_with_bound3: 0.8491
# Epoch 8/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5945 - binary_accuracy: 0.6842 - measure_with_bound1: 0.7349 - measure_with_bound2: 0.7938 - measure_with_bound3: 0.8495
# Epoch 9/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5941 - binary_accuracy: 0.6852 - measure_with_bound1: 0.7365 - measure_with_bound2: 0.7942 - measure_with_bound3: 0.8483
# Epoch 10/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5935 - binary_accuracy: 0.6854 - measure_with_bound1: 0.7371 - measure_with_bound2: 0.7942 - measure_with_bound3: 0.8494
# Epoch 11/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5932 - binary_accuracy: 0.6855 - measure_with_bound1: 0.7373 - measure_with_bound2: 0.7952 - measure_with_bound3: 0.8486
# Epoch 12/30
# 1290/1290 [==============================] - 7s 5ms/step - loss: 0.5930 - binary_accuracy: 0.6855 - measure_with_bound1: 0.7380 - measure_with_bound2: 0.7950 - measure_with_bound3: 0.8491
# Epoch 13/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5927 - binary_accuracy: 0.6856 - measure_with_bound1: 0.7379 - measure_with_bound2: 0.7949 - measure_with_bound3: 0.8492
# Epoch 14/30
# 1290/1290 [==============================] - 7s 5ms/step - loss: 0.5925 - binary_accuracy: 0.6857 - measure_with_bound1: 0.7386 - measure_with_bound2: 0.7951 - measure_with_bound3: 0.8491
# Epoch 15/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5924 - binary_accuracy: 0.6859 - measure_with_bound1: 0.7386 - measure_with_bound2: 0.7952 - measure_with_bound3: 0.8493
# Epoch 16/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5923 - binary_accuracy: 0.6862 - measure_with_bound1: 0.7391 - measure_with_bound2: 0.7953 - measure_with_bound3: 0.8491
# Epoch 17/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5920 - binary_accuracy: 0.6863 - measure_with_bound1: 0.7394 - measure_with_bound2: 0.7955 - measure_with_bound3: 0.8495
# Epoch 18/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5919 - binary_accuracy: 0.6860 - measure_with_bound1: 0.7385 - measure_with_bound2: 0.7963 - measure_with_bound3: 0.8486
# Epoch 19/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5917 - binary_accuracy: 0.6863 - measure_with_bound1: 0.7392 - measure_with_bound2: 0.7958 - measure_with_bound3: 0.8498
# Epoch 20/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5914 - binary_accuracy: 0.6864 - measure_with_bound1: 0.7393 - measure_with_bound2: 0.7966 - measure_with_bound3: 0.8496
# Epoch 21/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5914 - binary_accuracy: 0.6865 - measure_with_bound1: 0.7396 - measure_with_bound2: 0.7960 - measure_with_bound3: 0.8487
# Epoch 22/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5913 - binary_accuracy: 0.6862 - measure_with_bound1: 0.7399 - measure_with_bound2: 0.7959 - measure_with_bound3: 0.8492
# Epoch 23/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5912 - binary_accuracy: 0.6869 - measure_with_bound1: 0.7401 - measure_with_bound2: 0.7955 - measure_with_bound3: 0.8506
# Epoch 24/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5914 - binary_accuracy: 0.6862 - measure_with_bound1: 0.7401 - measure_with_bound2: 0.7960 - measure_with_bound3: 0.8497
# Epoch 25/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5911 - binary_accuracy: 0.6867 - measure_with_bound1: 0.7399 - measure_with_bound2: 0.7961 - measure_with_bound3: 0.8493
# Epoch 26/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5911 - binary_accuracy: 0.6872 - measure_with_bound1: 0.7401 - measure_with_bound2: 0.7962 - measure_with_bound3: 0.8487
# Epoch 27/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5911 - binary_accuracy: 0.6867 - measure_with_bound1: 0.7408 - measure_with_bound2: 0.7964 - measure_with_bound3: 0.8491
# Epoch 28/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5908 - binary_accuracy: 0.6870 - measure_with_bound1: 0.7405 - measure_with_bound2: 0.7960 - measure_with_bound3: 0.8492
# Epoch 29/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5909 - binary_accuracy: 0.6867 - measure_with_bound1: 0.7406 - measure_with_bound2: 0.7958 - measure_with_bound3: 0.8496
# Epoch 30/30
# 1290/1290 [==============================] - 6s 5ms/step - loss: 0.5907 - binary_accuracy: 0.6868 - measure_with_bound1: 0.7414 - measure_with_bound2: 0.7965 - measure_with_bound3: 0.8499

# %%
model2.evaluate(x_test, y_test, batch_size = 2048)
# Out:
# 81/81 [==============================] - 1s 4ms/step - loss: 0.5889 - binary_accuracy: 0.6882 - measure_with_bound1: 0.7470 - measure_with_bound2: 0.8046 - measure_with_bound3: 0.8643
# [0.5889211297035217,
#  0.6882290840148926,
#  0.7470332980155945,
#  0.8045710921287537,
#  0.8642696142196655]

# %%
#dataset = tf.data.Dataset.from_tensor_slices(x_test).batch(2048)

predictions = None

for x in dataset:
  pred = model2(x, training = False)
  if predictions == None:
    predictions = pred
  else:
    predictions = tf.concat([predictions, pred], axis = 0)

y = tf.reshape(tf.constant(y_test), shape = [-1, 1])

for i in range(5, 50, 5):
  b = i / 100.0
  acc, count = measure_with_bound_core(y, predictions, 0.5 - b, 0.5 + b, True)
  print('bound: {b:.2f}, accuracy: {acc: .4f}, count: {count}'.format(b = 0.5 + b, acc = acc, count = int(count)))
# Out:
# bound: 0.55, accuracy:  0.7199, count: 138528
# bound: 0.60, accuracy:  0.7470, count: 115128
# bound: 0.65, accuracy:  0.7746, count: 92725
# bound: 0.70, accuracy:  0.8045, count: 68531
# bound: 0.75, accuracy:  0.8356, count: 44975
# bound: 0.80, accuracy:  0.8643, count: 25045
# bound: 0.85, accuracy:  0.8885, count: 10242
# bound: 0.90, accuracy:  0.9099, count: 2631
# bound: 0.95, accuracy:  0.9395, count: 248
